# %% [markdown]
# <a href="https://colab.research.google.com/github/DionesGouvea/Michigan/blob/main/Applied%20Machine%20Learning%20in%20Python/Week%204/MachineLearning_assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Assignment 4**
#
# Prever e entender o envolvimento do espectador com vídeos educativos
# Com a popularidade acelerada das experiências educacionais online, o papel das palestras online e de outros vídeos educacionais continua a crescer em escopo e importância. Repositórios educacionais de acesso aberto, como videolectures.net, bem como Massive Open Online Courses (MOOCs) em plataformas como Coursera, tornaram o acesso a milhares de palestras e tutoriais uma opção acessível para milhões de pessoas em todo o mundo. No entanto, esse volume impressionante de conteúdo também levou a um desafio em como encontrar, filtrar e combinar esses vídeos com os alunos. Esta tarefa fornece um exemplo de como o aprendizado de máquina pode ser usado para enfrentar parte desse desafio.
#
#
# ###**Sobre o problema de previsão**
# Uma propriedade crítica de um vídeo é o engajamento: quão interessante ou "engajante" ele é para os espectadores, para que eles decidam continuar assistindo. O envolvimento é fundamental para o aprendizado, independentemente de a instrução vir de um vídeo ou de qualquer outra fonte. Há muitas maneiras de definir o envolvimento com o vídeo, mas uma abordagem comum é estimá-lo medindo quanto do vídeo um usuário assiste. Se o vídeo não for interessante e não envolver o espectador, ele normalmente o abandonará rapidamente, por exemplo. assistir apenas 5 ou 10% do total.
#
# Um primeiro passo para fornecer o conteúdo educacional mais adequado é entender quais recursos do material educacional o tornam atraente para os alunos em geral. É aqui que a modelagem preditiva pode ser aplicada, por meio do aprendizado de máquina supervisionado. Para esta tarefa, sua tarefa é prever a probabilidade de envolvimento de um vídeo educacional para os espectadores, com base em um conjunto de recursos extraídos da transcrição do vídeo, faixa de áudio, site de hospedagem e outras fontes.
#
# **Escolhemos esse problema de previsão por vários motivos:**
#
# Ele combina uma variedade de recursos derivados de um rico conjunto de recursos conectados aos dados originais;
# O tamanho gerenciável do conjunto de dados significa que o conjunto de dados e os modelos supervisionados podem ser facilmente explorados em uma ampla variedade de plataformas de computação;
# Prever a popularidade ou o engajamento de um item de mídia, especialmente combinado com a compreensão de quais recursos contribuem para seu sucesso com os espectadores, é um problema divertido, mas também uma aplicação prática e representativa do aprendizado de máquina em vários setores empresariais e educacionais.
#
# ###**Sobre o conjunto de dados**
# Extraímos conjuntos de dados de treinamento e teste de recursos de vídeo educacional do VLE Dataset reunidos pelo pesquisador Sahan Bulathwela na University College London.
#
# Fornecemos dois arquivos de dados para uso no treinamento e validação de seus modelos: train.csv e test.csv. Cada linha desses dois arquivos corresponde a um único vídeo educacional e inclui informações sobre diversas propriedades do conteúdo do vídeo, conforme descrito abaixo. A variável de destino é o engajamento, que foi definido como Verdadeiro se a porcentagem mediana do vídeo assistido por todos os visualizadores for de pelo menos 30% e Falso caso contrário.
#
# **Observação:** Quaisquer variáveis ​​extras que possam ser incluídas no conjunto de treinamento são simplesmente de seu interesse, se você deseja uma fonte adicional de dados para visualização ou para permitir abordagens não supervisionadas e semissupervisionadas. No entanto, eles não estão incluídos no conjunto de teste e, portanto, não podem ser usados ​​para previsão. Somente os dados já incluídos no diretório do Coursera podem ser usados ​​para treinar o modelo para esta tarefa.
#
# Para esta tarefa final, você reunirá o que aprendeu nas quatro semanas deste curso, explorando diferentes modelos de previsão para este novo conjunto de dados. Além disso, encorajamos você a aplicar o que aprendeu sobre seleção de modelo para fazer o ajuste de hiperparâmetro usando divisões de treinamento/validação dos dados de treinamento, para otimizar o modelo e aumentar ainda mais seu desempenho. Além de uma avaliação básica da precisão do modelo, também fornecemos uma função de utilidade para visualizar quais recursos contribuem mais e menos para o desempenho geral do modelo.
#
# **Descrições de arquivo assets/train.csv** - o conjunto de treinamento (use apenas esses dados para treinar seu modelo!) assets/test.csv - o conjunto de teste

# %% [markdown]
# ###Descrição das Features
#
# **title_word_count** - o número de palavras no título do vídeo.
#
# **document_entropy** - uma pontuação que indica a variedade de tópicos abordados no vídeo, com base na transcrição. Vídeos com pontuações de entropia menores tendem a ser mais coesos e mais focados em um único tópico.
#
# **freshness** - Número de dias decorridos entre 01/01/1970 e a data de publicação da palestra. Os vídeos mais recentes terão valores de atualização mais altos.
#
# **easiness** - Uma medida de dificuldade de texto aplicada à transcrição. Uma pontuação mais baixa indica linguagem mais complexa usada pelo apresentador.
#
# **fraction_stopword_presence**  - Uma palavra irrelevante é uma palavra muito comum como 'o' ou 'e'. Esse recurso calcula a fração de todas as palavras que são stopwords na transcrição da palestra em vídeo.
#
# **speaker_speed** - A taxa média de fala em palavras por minuto do apresentador no vídeo.
#
# **silent_period_rate** - A fração de tempo no vídeo da palestra que é silêncio (sem fala).
#
# ---
#
# ####**train.csv apenas:**
#
# **engagement** - Rótulo alvo para treinamento. Verdadeiro se os alunos assistiram a uma parte substancial do vídeo (consulte a descrição) ou Falso caso contrário.

# %% [markdown]
# ###**Avaliação**
# Suas previsões serão dadas como a probabilidade de que o vídeo correspondente seja atraente para os alunos.
#
# A métrica de avaliação para esta tarefa é a Área sob a Curva ROC (AUC).
#
# Sua nota será baseada na pontuação AUC calculada para seu classificador. Um modelo com uma AUC (área sob a curva ROC) de pelo menos 0,8 passa nesta atribuição e acima de 0,85 receberá pontos completos.
#
# -------------------------------------
#
# Para esta tarefa, crie uma função que treine um modelo para prever o envolvimento significativo do aluno com um vídeo usando asset/train.csv. Usando este modelo, retorne um objeto Pandas Series de comprimento 2309 com os dados sendo a probabilidade de que cada vídeo correspondente de readonly/test.csv seja envolvente (de acordo com um modelo aprendido com o rótulo 'engajamento' no conjunto de treinamento) e o índice de vídeo está no campo id.
#
# Exemplo:
#
#     ID
#     9240 0,401958
#     9241 0,105928
#     9242 0,018572
#              ...
#     9243 0,208567
#     9244 0,818759
#     9245 0,018528
#          ...
#     Name: engagement, dtype: float32

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)   # Do not change this value: required to be compatible with solutions generated by the autograder.

# %% [markdown]
# ### Analise exploratoria

# %%
df = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9239 entries, 0 to 9238
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          9239 non-null   int64
#  1   title_word_count            9239 non-null   int64
#  2   document_entropy            9239 non-null   float64
#  3   freshness                   9239 non-null   int64
#  4   easiness                    9239 non-null   float64
#  5   fraction_stopword_presence  9239 non-null   float64
#  6   normalization_rate          9239 non-null   float64
#  7   speaker_speed               9239 non-null   float64
#  8   silent_period_rate          9239 non-null   float64
#  9   engagement                  9239 non-null   bool
# dtypes: bool(1), float64(6), int64(3)
# memory usage: 658.8 KB

# %%
df.head()
# Out:
#    id  title_word_count  document_entropy  freshness   easiness  \
# 0   1                 9          7.753995      16310  75.583936
# 1   2                 6          8.305269      15410  86.870523
# 2   3                 3          7.965583      15680  81.915968
# 3   4                 9          8.142877      15610  80.148937
# 4   5                 9          8.161250      14920  76.907549
#
#    fraction_stopword_presence  normalization_rate  speaker_speed  \
# 0                    0.553664            0.034049       2.997753
# 1                    0.584498            0.018763       2.635789
# 2                    0.605685            0.030720       2.538095
# 3                    0.593664            0.016873       2.259055
# 4                    0.581637            0.023412       2.420000
#
#    silent_period_rate  engagement
# 0                 0.0        True
# 1                 0.0       False
# 2                 0.0       False
# 3                 0.0       False
# ...

# %%
df.engagement.value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.scatterplot(x='easiness', y='speaker_speed', hue='engagement', data=df)
# Out:
# <Axes: xlabel='easiness', ylabel='speaker_speed'>

# %% [markdown]
# Conteudos mais complexos que são ensinados com uma fala mais lenta do professor, retem mais o engajamento do aluno

# %%
sns.boxplot(x='engagement', y='freshness', data=df)
# Out:
# <Axes: xlabel='engagement', ylabel='freshness'>

# %% [markdown]
# Videos mais recentes tem um maior engajamento do aluno

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.histplot(data=df, x='document_entropy',hue = 'engagement', bins=20)

plt.subplot(1,2,2)
sns.histplot(data=df, x='fraction_stopword_presence',hue = 'engagement', bins=20)
# Out:
# <Axes: xlabel='fraction_stopword_presence', ylabel='Count'>

# %% [markdown]
# a quantidade de assuntos abordados e stopwords não aparentam ter muito influencia sobre o engajamento

# %%
sns.boxplot(x='engagement', y='title_word_count', data=df)
# Out:
# <Axes: xlabel='engagement', ylabel='title_word_count'>

# %% [markdown]
# o numero de palavras no titulo do video aparentemente não afeta no engajamento

# %% [markdown]
# ### Dados de Treinamento

# %%
X = df.drop('engagement', axis = 1)
y = df['engagement']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred_proba = rfc.predict_proba(X_test)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba[:, 1]) # pegando a segunda coluna do predict_proba(positiva)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Dados de Teste

# %%
# Separarando as colunas de recursos e a variável target
X_train = df.drop(['id', 'engagement'], axis=1)
y_train = df['engagement']


rfc.fit(X_train, y_train)

# Prevendo a probabilidade de envolvimento significativo do aluno para os dados de teste
X_test = test_data.drop('id', axis=1)
y_pred_proba = rfc.predict_proba(X_test)[:, 1] # pegando a segunda coluna do predict_proba(positiva)

# Salvando as probabilidades previstas em um objeto pandas series
predictions = pd.Series(y_pred_proba, index=test_data['id'], name='engagement')

# %%
predictions
# Out:
# id
# 9240     0.00
# 9241     0.08
# 9242     0.09
# 9243     0.88
# 9244     0.04
#          ...
# 11544    0.01
# 11545    0.01
# 11546    0.01
# 11547    0.94
# 11548    0.01
# Name: engagement, Length: 2309, dtype: float64
